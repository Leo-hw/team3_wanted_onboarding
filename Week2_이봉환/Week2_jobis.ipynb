# %%
# !apt -qq -y install fonts-nanum > /dev/null
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
### 라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# df = pd.concat(pd.read_csv(archive.open(filename)) for filename in archive.namelist())

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Jobis_3o3.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   age        100000 non-null  float64
#  1   gender     100000 non-null  object
#  2   year       100000 non-null  int64
#  3   refund     100000 non-null  float64
#  4   fee        100000 non-null  float64
#  5   has_paid   100000 non-null  bool
#  6   income_근로  40791 non-null   float64
#  7   income_사업  78227 non-null   float64
#  8   income_기타  25260 non-null   float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#                 age           year  ...     income_사업     income_기타
# count  100000.00000  100000.000000  ...  7.822700e+04  2.526000e+04
# mean       29.00096    2018.111300  ...  1.511712e+06  6.362834e+05
# std         7.76819       1.495812  ...  2.449810e+06  1.484947e+06
# min        15.00000    2015.000000  ...  0.000000e+00  0.000000e+00
# 25%        24.00000    2017.000000  ...  1.770000e+05  8.200000e+04
# 50%        27.00000    2018.000000  ...  6.190000e+05  2.130000e+05
# 75%        31.00000    2019.000000  ...  1.601000e+06  5.820000e+05
# max        81.00000    2020.000000  ...  3.993400e+07  6.281000e+07
#
# [8 rows x 7 columns]

# %%
df.head(10)
# Out:
#     age gender  year     refund  ...  has_paid   income_근로  income_사업  income_기타
# 0  27.0      F  2019     5000.0  ...     False  10001000.0    61000.0        NaN
# 1  34.0      M  2018   100000.0  ...      True  18092000.0        NaN  1815000.0
# 2  28.0      F  2017   289000.0  ...     False         NaN  1461000.0        NaN
# 3  27.0      M  2019   410000.0  ...     False         NaN  2471000.0        NaN
# 4  26.0      F  2016   114000.0  ...      True         0.0   689000.0        NaN
# 5  39.0      F  2015   546000.0  ...      True         NaN  3628000.0   213000.0
# 6  40.0      F  2019     4000.0  ...      True  11512000.0    24000.0        NaN
# 7  23.0      M  2017    10000.0  ...      True    186000.0    74000.0        NaN
# 8  54.0      M  2016  1847000.0  ...     False  18728000.0        NaN  2841000.0
# 9  22.0      M  2018    51000.0  ...     False         NaN        NaN   153000.0
#
# [10 rows x 9 columns]

# %%
#  df[df['has_paid']==2019].index.tolist()
year15 = df[df['year']==2015].index.tolist()
year16 = df[df['year']==2016].index.tolist()
year17 = df[df['year']==2017].index.tolist()
year18 = df[df['year']==2018].index.tolist()
year19 = df[df['year']==2019].index.tolist()
year20 = df[df['year']==2020].index.tolist()

# %%
df15 = df[df.index.isin(year15)]
df16 = df[df.index.isin(year16)]
df17 = df[df.index.isin(year17)]
df18 = df[df.index.isin(year18)]
df19 = df[df.index.isin(year19)]
df20 = df[df.index.isin(year20)]

# %%
import matplotlib as mpl
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

mpl.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(figsize=(16, 10))
heatdf15 = df15[[ 'age',	'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타']]
sns.heatmap(heatdf15.corr(), cmap='BuPu', annot = True, cbar=True, )

fig, ax = plt.subplots(figsize=(16, 10))
heatdf16 = df16[['age',	'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타']]
sns.heatmap(heatdf16.corr(), cmap='BrBG', annot = True, cbar=True, )

fig, ax = plt.subplots(figsize=(16, 10))
heatdf17 = df17[['age',	'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타']]
sns.heatmap(heatdf17.corr(), cmap='BrBG', annot = True, cbar=True, )

fig, ax = plt.subplots(figsize=(16, 10))
heatdf18 = df18[['age',	'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타']]
sns.heatmap(heatdf18.corr(), cmap='BrBG', annot = True, cbar=True, )

fig, ax = plt.subplots(figsize=(16, 10))
heatdf19 = df19[['age',	'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타']]
sns.heatmap(heatdf19.corr(), cmap='BrBG', annot = True, cbar=True, )

fig, ax = plt.subplots(figsize=(16, 10))
heatdf20 = df20[['age',	'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타']]
sns.heatmap(heatdf20.corr(), cmap='BrBG', annot = True, cbar=True, )


plt.show()

# %%
print(df15.corr().query('has_paid > 0.3 or has_paid < -0.3').index.values.tolist())
print(df16.corr().query('has_paid > 0.3 or has_paid < -0.3').index.values.tolist())
print(df17.corr().query('has_paid > 0.3 or has_paid < -0.3').index.values.tolist())
print(df18.corr().query('has_paid > 0.3 or has_paid < -0.3').index.values.tolist())
print(df19.corr().query('has_paid > 0.3 or has_paid < -0.3').index.values.tolist())
print(df20.corr().query('has_paid > 0.3 or has_paid < -0.3').index.values.tolist())
# Out:
# ['has_paid']
# ['has_paid']
# ['has_paid']
# ['has_paid']
# ['has_paid']
# ['has_paid']

# %%
### 결측치 확인
df.isnull().sum()
# Out:
# age              0
# gender           0
# year             0
# refund           0
# fee              0
# has_paid         0
# income_근로    59209
# income_사업    21773
# income_기타    74740
# dtype: int64

# %%
### 결측값이 있는 인덱스 확인
print(np.where(df.income_근로.isnull()))
print(np.where(df.income_사업.isnull()))
print(np.where(df.income_기타.isnull()))
# Out:
# (array([    2,     3,     5, ..., 99995, 99996, 99998]),)
# (array([    1,     8,     9, ..., 99992, 99994, 99995]),)
# (array([    0,     2,     3, ..., 99997, 99998, 99999]),)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'year', 'refund', 'fee', 'has_paid', 'income_근로',
#        'income_사업', 'income_기타'],
#       dtype='object')

# %%
# 환급금 대비 수수료 비율
df['환급금_수수료율'] = round(df['fee']/df['refund'], 4) *100
df
# Out:
#         age gender  year    refund  ...   income_근로  income_사업  income_기타  환급금_수수료율
# 0      27.0      F  2019    5000.0  ...  10001000.0    61000.0        NaN      8.00
# 1      34.0      M  2018  100000.0  ...  18092000.0        NaN  1815000.0      1.70
# 2      28.0      F  2017  289000.0  ...         NaN  1461000.0        NaN      3.98
# 3      27.0      M  2019  410000.0  ...         NaN  2471000.0        NaN      3.95
# 4      26.0      F  2016  114000.0  ...         0.0   689000.0        NaN      3.77
# ...     ...    ...   ...       ...  ...         ...        ...        ...       ...
# 99995  27.0      F  2019  301000.0  ...         NaN        NaN   680000.0      3.95
# 99996  62.0      F  2019   77000.0  ...         NaN   463000.0        NaN      1.69
# 99997  24.0      M  2020    9000.0  ...   7923000.0    54000.0        NaN      4.44
# 99998  24.0      M  2019   34000.0  ...         NaN   204000.0        NaN      1.18
# 99999  23.0      F  2019   34000.0  ...   7344000.0   205000.0        NaN      1.18
#
# [100000 rows x 10 columns]

# %%
# 근로 수입이 가장 큰 경우
emp_list = df.query('income_근로 > income_사업 and income_근로 > income_기타').index.values.tolist()
# 사업 소득이 가장 큰 경우
bus_list = df.query('income_근로 < income_사업 and income_사업 > income_기타').index.values.tolist()
# 기타 수입이 제일 큰 경우
etc_list = df.query('income_기타 > income_사업 and income_근로 < income_기타').index.values.tolist()

# %%
print(len(emp_list), '\t', len(bus_list), '\t', len(etc_list))
# Out:
# 4822 	 887 	 271

# %%
## 모든 수입이 동일한 값 확인
df.query('income_근로 == income_사업 == income_기타')
# Out:
# Empty DataFrame
# Columns: [age, gender, year, refund, fee, has_paid, income_근로, income_사업, income_기타, 환급금_수수료율]
# Index: []

# %%
## 모든 수입이 0인 값이 있는 지 확인.
df.query('income_근로 ==0 and income_사업 ==0 and income_기타==0')
# Out:
# Empty DataFrame
# Columns: [age, gender, year, refund, fee, has_paid, income_근로, income_사업, income_기타, 환급금_수수료율]
# Index: []

# %%
## 모든 수입이 NaN인 값 확인
# df.query('income_근로 =="NaN"')
df.query('income_근로 =="NaN" and income_사업 == "NaN" and income_기타 == "NaN"')
# Out:
#         age gender  year    refund  ...  income_근로  income_사업  income_기타  환급금_수수료율
# 20     40.0      F  2018   46000.0  ...        NaN        NaN        NaN      0.87
# 24     33.0      M  2018   21000.0  ...        NaN        NaN        NaN      1.90
# 33     22.0      M  2018   69000.0  ...        NaN        NaN        NaN      0.58
# 41     32.0      M  2019  251000.0  ...        NaN        NaN        NaN      2.87
# 43     35.0      M  2015  568000.0  ...        NaN        NaN        NaN      2.25
# ...     ...    ...   ...       ...  ...        ...        ...        ...       ...
# 99979  34.0      M  2016  189000.0  ...        NaN        NaN        NaN      2.28
# 99984  25.0      F  2018  286000.0  ...        NaN        NaN        NaN      2.97
# 99988  45.0      M  2018  152000.0  ...        NaN        NaN        NaN      2.83
# 99992  25.0      F  2018  137000.0  ...        NaN        NaN        NaN      2.77
# 99994  32.0      M  2016  101000.0  ...        NaN        NaN        NaN      2.97
#
# [9214 rows x 10 columns]

# %%
len(etc_list) + len(emp_list) + len(bus_list)
## income 값을 채워줘야 할 필요성 
## nan 값을 0으로 채우기

df['income_근로'] = df['income_근로'].fillna(0)
df['income_사업'] = df['income_사업'].fillna(0)
df['income_기타'] = df['income_기타'].fillna(0)

# %%
df.query('income_근로 == "NaN"')
# Out:
# Empty DataFrame
# Columns: [age, gender, year, refund, fee, has_paid, income_근로, income_사업, income_기타, 환급금_수수료율]
# Index: []

# %%
emp_list = df.query('income_근로 > income_사업 and income_근로 > income_기타').index.values.tolist()
# 사업 소득이 가장 큰 경우
bus_list = df.query('income_근로 < income_사업 and income_사업 > income_기타').index.values.tolist()
# 기타 수입이 제일 큰 경우
etc_list = df.query('income_기타 > income_사업 and income_근로 < income_기타').index.values.tolist()

# %%
print(len(emp_list), '\t', len(bus_list), '\t', len(etc_list), '\t합은 {} '.format(len(emp_list)+ len(bus_list) +len(etc_list)) )
# Out:
# 33323 	 49388 	 8009 	합은 90720

# %%
## 모든 수입이 0인 값이 있는 지 확인.
df.query('income_근로 ==0 and income_사업 ==0 and income_기타==0').index.unique().tolist() == df.query('income_근로 == income_사업 == income_기타').index.tolist() # True
# 모든 소득이 0 인 경우와 모든 소득이 동일한 경우가 일치.

no_money = df.query('income_근로 == income_사업 == income_기타').index.tolist()
# no_money = no_df.query('income_근로 == income_사업 == income_기타').index.tolist()
print(len(no_money))
# Out:
# 9226

# %%
(len(emp_list)+ len(bus_list) +len(etc_list)) + len(df.query('income_근로 ==0 and income_사업 ==0 and income_기타==0').index.unique().tolist())
# Out:
# 99946

# %%
## 모든 수입이 동일한 값 확인
df.query('income_근로 == income_사업 == income_기타')
# Out:
#         age gender  year    refund  ...  income_근로  income_사업  income_기타  환급금_수수료율
# 20     40.0      F  2018   46000.0  ...        0.0        0.0        0.0      0.87
# 24     33.0      M  2018   21000.0  ...        0.0        0.0        0.0      1.90
# 33     22.0      M  2018   69000.0  ...        0.0        0.0        0.0      0.58
# 41     32.0      M  2019  251000.0  ...        0.0        0.0        0.0      2.87
# 43     35.0      M  2015  568000.0  ...        0.0        0.0        0.0      2.25
# ...     ...    ...   ...       ...  ...        ...        ...        ...       ...
# 99979  34.0      M  2016  189000.0  ...        0.0        0.0        0.0      2.28
# 99984  25.0      F  2018  286000.0  ...        0.0        0.0        0.0      2.97
# 99988  45.0      M  2018  152000.0  ...        0.0        0.0        0.0      2.83
# 99992  25.0      F  2018  137000.0  ...        0.0        0.0        0.0      2.77
# 99994  32.0      M  2016  101000.0  ...        0.0        0.0        0.0      2.97
#
# [9226 rows x 10 columns]

# %%
## 모든 소득이 동일 and 소득이 0
no_list = list(set(emp_list) | set(bus_list) | set(etc_list))
no_df = df[~df.index.isin(no_list)]

print(df.query('income_근로 == income_사업 == income_기타 and income_근로 != 0').index.tolist())
## 소득이 0이 아니면서 동일한 값은 없음.
# Out:
# []

# %%
len(no_list)
# Out:
# 90720

# %%
no_df
# Out:
#         age gender  year    refund  ...  income_근로  income_사업  income_기타  환급금_수수료율
# 20     40.0      F  2018   46000.0  ...        0.0        0.0        0.0      0.87
# 24     33.0      M  2018   21000.0  ...        0.0        0.0        0.0      1.90
# 33     22.0      M  2018   69000.0  ...        0.0        0.0        0.0      0.58
# 41     32.0      M  2019  251000.0  ...        0.0        0.0        0.0      2.87
# 43     35.0      M  2015  568000.0  ...        0.0        0.0        0.0      2.25
# ...     ...    ...   ...       ...  ...        ...        ...        ...       ...
# 99979  34.0      M  2016  189000.0  ...        0.0        0.0        0.0      2.28
# 99984  25.0      F  2018  286000.0  ...        0.0        0.0        0.0      2.97
# 99988  45.0      M  2018  152000.0  ...        0.0        0.0        0.0      2.83
# 99992  25.0      F  2018  137000.0  ...        0.0        0.0        0.0      2.77
# 99994  32.0      M  2016  101000.0  ...        0.0        0.0        0.0      2.97
#
# [9280 rows x 10 columns]

# %%
no_etc = no_df.query('income_근로 == income_사업 != income_기타').index.tolist()
len(no_df.query('income_근로 == income_사업 != income_기타').index)
# Out:
# 16

# %%
df.query('income_근로 != income_사업 == income_기타')
# Out:
#         age gender  year    refund  ...   income_근로  income_사업  income_기타  환급금_수수료율
# 333    32.0      M  2016   85000.0  ...   9165000.0        0.0        0.0      2.47
# 1193   32.0      M  2019   88000.0  ...  12261000.0        0.0        0.0      4.89
# 1984   26.0      F  2019    4000.0  ...         0.0    21000.0    21000.0     10.00
# 2501   26.0      F  2016    4000.0  ...   2210000.0        0.0        0.0     10.00
# 3192   29.0      M  2018   58000.0  ...   1737000.0        0.0        0.0      1.55
# ...     ...    ...   ...       ...  ...         ...        ...        ...       ...
# 97696  23.0      M  2017  222000.0  ...   1364000.0        0.0        0.0      3.83
# 97913  28.0      F  2020   20000.0  ...  11696000.0    43000.0    43000.0      2.00
# 97940  29.0      F  2018  540000.0  ...  12245000.0        0.0        0.0      3.94
# 98071  45.0      F  2016   62000.0  ...   1542000.0        0.0        0.0      1.45
# 98281  30.0      F  2020  143000.0  ...  13790000.0        0.0        0.0      3.85
#
# [148 rows x 10 columns]

# %%
print(len(df.query('income_근로 != income_사업 == income_기타').index))
print(len(no_df.query('income_근로 != income_사업 == income_기타').index))
no_work = no_df.query('income_근로 != income_사업 == income_기타').index.tolist()
no_df.query('income_근로 != income_사업 == income_기타')
# Out:
# 148
# 37
#         age gender  year    refund  ...  income_근로  income_사업  income_기타  환급금_수수료율
# 1984   26.0      F  2019    4000.0  ...        0.0    21000.0    21000.0     10.00
# 3369   32.0      M  2018    7000.0  ...        0.0    43000.0    43000.0      5.71
# 3864   22.0      M  2018   98000.0  ...        0.0    77000.0    77000.0      1.73
# 6073   48.0      M  2017  494000.0  ...        0.0  2976000.0  2976000.0      2.59
# 8428   25.0      M  2018   21000.0  ...        0.0   128000.0   128000.0      1.90
# 9912   23.0      F  2018    7000.0  ...        0.0    43000.0    43000.0      5.71
# 11636  22.0      M  2016    7000.0  ...        0.0    43000.0    43000.0      5.71
# 21438  21.0      M  2019    7000.0  ...        0.0    43000.0    43000.0      5.71
# 21990  21.0      F  2019   20000.0  ...        0.0   119000.0   119000.0      2.00
# 26501  43.0      F  2017   49000.0  ...        0.0   128000.0   128000.0      1.84
# 27970  21.0      F  2020   14000.0  ...        0.0    85000.0    85000.0      2.86
# 33642  29.0      F  2015  183000.0  ...        0.0  1105000.0  1105000.0      2.35
# 34327  28.0      M  2017   35000.0  ...        0.0   213000.0   213000.0      1.14
# 34579  25.0      M  2018    5000.0  ...        0.0    30000.0    30000.0      8.00
# 36757  22.0      F  2020   33000.0  ...        0.0   201000.0   201000.0      1.21
# 37210  21.0      M  2018   85000.0  ...        0.0   170000.0   170000.0      1.53
# 41964  27.0      M  2018   35000.0  ...        0.0   213000.0   213000.0      1.14
# 48563  22.0      F  2019  103000.0  ...        0.0   170000.0   170000.0      1.65
# 52250  23.0      F  2017    7000.0  ...        0.0    43000.0    43000.0      5.71
# 52509  27.0      M  2020    4000.0  ...        0.0    21000.0    21000.0     10.00
# 53155  28.0      M  2015    7000.0  ...        0.0    43000.0    43000.0      5.71
# 57400  36.0      M  2016   42000.0  ...        0.0   255000.0   255000.0      0.95
# 58340  25.0      F  2020    4000.0  ...        0.0    21000.0    21000.0     10.00
# 58698  22.0      F  2017    7000.0  ...        0.0    43000.0    43000.0      5.71
# 59549  23.0      M  2018    4000.0  ...        0.0    21000.0    21000.0     10.00
# 61733  27.0      M  2019  517000.0  ...        0.0   850000.0   850000.0      3.95
# 65734  18.0      M  2019  132000.0  ...        0.0   340000.0   340000.0      3.86
# 69837  32.0      F  2020   45000.0  ...        0.0    35000.0    35000.0      2.00
# 72780  20.0      M  2016   66000.0  ...        0.0   170000.0   170000.0      1.97
# 77634  23.0      M  2016   66000.0  ...        0.0   170000.0   170000.0      1.97
# 78126  20.0      F  2019    6000.0  ...        0.0    36000.0    36000.0      6.67
# 78709  21.0      M  2019   59000.0  ...        0.0   128000.0   128000.0      1.53
# 82521  24.0      F  2018    9000.0  ...        0.0    53000.0    53000.0      4.44
# 83604  29.0      M  2020    7000.0  ...        0.0    43000.0    43000.0      5.71
# 90449  24.0      F  2018   11000.0  ...        0.0    64000.0    64000.0      3.64
# 93852  20.0      F  2017   66000.0  ...        0.0   170000.0   170000.0      1.97
# 95275  27.0      F  2018   53000.0  ...        0.0   106000.0   106000.0      1.70
#
# [37 rows x 10 columns]

# %%
print(len(df.query('income_근로 == income_기타 != income_사업').index))
no_busi = no_df.query('income_근로 == income_기타 != income_사업').index.tolist()
no_df.query('income_근로 == income_기타 != income_사업')
# Out:
# 38434
#         age gender  year    refund  ...  income_근로  income_사업  income_기타  환급금_수수료율
# 36539  25.0      M  2020  465000.0  ...   850000.0   531000.0   850000.0      3.94
#
# [1 rows x 10 columns]

# %%
len(no_work)+len(no_busi) + len(no_etc)
# Out:
# 54

# %% [markdown]
# 새로운 컬럼 income_cat 생성
#
# 주요 소득 군 설정
# 근로:0
# 사업:1
# 기타:2
# 근로==사업:3
# 사업==기타:4
# 근로==기타:5
# 소득 없음:6

# %%
empty = []
count = 0

from tqdm import tqdm
df['income_cat']  = 6
for i in tqdm(df.index, position=0, leave=True):
  if i in emp_list:
    df['income_cat'][i] = 0
    # print(i)
  if i in bus_list:
    df['income_cat'][i] = 1
    # print(i)
  if i in etc_list:
    df['income_cat'][i] = 2
  if i in no_work:
    df['income_cat'][i] = 3
  if i in no_busi:
    df['income_cat'][i] = 4
  if i in no_etc:
    df['income_cat'][i] = 5
  if i in no_money:
    df['income_cat'][i] = 6
# Out:
# 100%|██████████| 100000/100000 [03:14<00:00, 512.82it/s]

# %%
df[df['income_cat']==6]
# Out:
#         age gender  year    refund  ...  income_사업  income_기타  환급금_수수료율  income_cat
# 20     40.0      F  2018   46000.0  ...        0.0        0.0      0.87           6
# 24     33.0      M  2018   21000.0  ...        0.0        0.0      1.90           6
# 33     22.0      M  2018   69000.0  ...        0.0        0.0      0.58           6
# 41     32.0      M  2019  251000.0  ...        0.0        0.0      2.87           6
# 43     35.0      M  2015  568000.0  ...        0.0        0.0      2.25           6
# ...     ...    ...   ...       ...  ...        ...        ...       ...         ...
# 99979  34.0      M  2016  189000.0  ...        0.0        0.0      2.28           6
# 99984  25.0      F  2018  286000.0  ...        0.0        0.0      2.97           6
# 99988  45.0      M  2018  152000.0  ...        0.0        0.0      2.83           6
# 99992  25.0      F  2018  137000.0  ...        0.0        0.0      2.77           6
# 99994  32.0      M  2016  101000.0  ...        0.0        0.0      2.97           6
#
# [9226 rows x 11 columns]

# %%
## 결제 여부 데이터 타입 변경
## 결제 했을 경우 0, 아닐 경우 1

df.query('has_paid == False')
def make_binary(sent):
  if sent is True:
    sent = 0
  else:
    sent = 1
  return sent

# %%
df['has_paid']= df['has_paid'].apply(lambda x: make_binary(x))
df
# Out:
#         age gender  year    refund  ...  income_사업  income_기타  환급금_수수료율  income_cat
# 0      27.0      F  2019    5000.0  ...    61000.0        0.0      8.00           0
# 1      34.0      M  2018  100000.0  ...        0.0  1815000.0      1.70           0
# 2      28.0      F  2017  289000.0  ...  1461000.0        0.0      3.98           1
# 3      27.0      M  2019  410000.0  ...  2471000.0        0.0      3.95           1
# 4      26.0      F  2016  114000.0  ...   689000.0        0.0      3.77           1
# ...     ...    ...   ...       ...  ...        ...        ...       ...         ...
# 99995  27.0      F  2019  301000.0  ...        0.0   680000.0      3.95           2
# 99996  62.0      F  2019   77000.0  ...   463000.0        0.0      1.69           1
# 99997  24.0      M  2020    9000.0  ...    54000.0        0.0      4.44           0
# 99998  24.0      M  2019   34000.0  ...   204000.0        0.0      1.18           1
# 99999  23.0      F  2019   34000.0  ...   205000.0        0.0      1.18           0
#
# [100000 rows x 11 columns]

# %%
# gender 컬럼 데이터 값 변환
# 남자는 0, 여자는 1

def make_gen_bin(sent):
  if sent == 'M':
    sent = 0
  if sent == 'F':
    sent = 1
  return sent
df['gender'] = df['gender'].apply(lambda x: make_gen_bin(x))

# %%
df
# Out:
#         age gender  year    refund  ...  income_사업  income_기타  환급금_수수료율  income_cat
# 0      27.0      1  2019    5000.0  ...    61000.0        0.0      8.00           0
# 1      34.0      0  2018  100000.0  ...        0.0  1815000.0      1.70           0
# 2      28.0      1  2017  289000.0  ...  1461000.0        0.0      3.98           1
# 3      27.0      0  2019  410000.0  ...  2471000.0        0.0      3.95           1
# 4      26.0      1  2016  114000.0  ...   689000.0        0.0      3.77           1
# ...     ...    ...   ...       ...  ...        ...        ...       ...         ...
# 99995  27.0      1  2019  301000.0  ...        0.0   680000.0      3.95           2
# 99996  62.0      1  2019   77000.0  ...   463000.0        0.0      1.69           1
# 99997  24.0      0  2020    9000.0  ...    54000.0        0.0      4.44           0
# 99998  24.0      0  2019   34000.0  ...   204000.0        0.0      1.18           1
# 99999  23.0      1  2019   34000.0  ...   205000.0        0.0      1.18           0
#
# [100000 rows x 11 columns]

# %%
import matplotlib as mpl
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

mpl.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(figsize=(16, 10))
heat_df = df[['age',	'gender',	'year',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타',	'환급금_수수료율',	'income_cat']]
sns.heatmap(heat_df.corr(), cmap='BrBG', annot = True, cbar=True, )

plt.show()

# %%
def make_age_group(sent):
  if sent < 20 and sent >=10:
    age_group =   0
  if sent < 30 and sent >=20:
    age_group =   1
  if sent < 40 and sent >=30:
    age_group =   2
  if sent < 50 and sent >=40:
    age_group =   3
  if sent < 60 and sent >=50:
    age_group =   4
  if sent < 70 and sent >=60:
    age_group =   5
  if sent < 80 and sent >=70:
    age_group =   6
  if sent < 90 and sent >=80:
    age_group =   7
  if sent < 100 and sent >=90:
    age_group =   8
  
  return age_group

# 10대 0
# 20대 1
# 30대 2
# 40대 3
# 50대 4
# 60대 5
# 70대 6
# 80대 7
# 90대 8

# %%
df['age_group'] = df['age'].apply(lambda x : make_age_group(x))

# %%
df
# Out:
#         age gender  year    refund  ...  income_기타  환급금_수수료율  income_cat  age_group
# 0      27.0      1  2019    5000.0  ...        0.0      8.00           0          1
# 1      34.0      0  2018  100000.0  ...  1815000.0      1.70           0          2
# 2      28.0      1  2017  289000.0  ...        0.0      3.98           1          1
# 3      27.0      0  2019  410000.0  ...        0.0      3.95           1          1
# 4      26.0      1  2016  114000.0  ...        0.0      3.77           1          1
# ...     ...    ...   ...       ...  ...        ...       ...         ...        ...
# 99995  27.0      1  2019  301000.0  ...   680000.0      3.95           2          1
# 99996  62.0      1  2019   77000.0  ...        0.0      1.69           1          5
# 99997  24.0      0  2020    9000.0  ...        0.0      4.44           0          1
# 99998  24.0      0  2019   34000.0  ...        0.0      1.18           1          1
# 99999  23.0      1  2019   34000.0  ...        0.0      1.18           0          1
#
# [100000 rows x 12 columns]

# %%
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

mpl.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(figsize=(16, 10))
heat_df = df[['year', 'gender',	'refund',	'fee'	,'has_paid'	,'income_근로',	'income_사업',	'income_기타',	'환급금_수수료율',	'income_cat', 'age_group']]
sns.heatmap(heat_df.corr(), cmap='BrBG', annot = True, cbar=True, )

plt.show()

# %%
heat_df.corr().query('has_paid > 0.3 or has_paid < -0.3')
# Out:
#                 year    refund       fee  ...  환급금_수수료율  income_cat  age_group
# has_paid    0.136060  0.094061  0.117695  ...  0.021294    0.310678   0.023724
# income_cat -0.214491  0.017101  0.002252  ...  0.004362    1.000000   0.008355
#
# [2 rows x 10 columns]

# %%
heat_df.corr()
# Out:
#                 year    refund       fee  ...  환급금_수수료율  income_cat  age_group
# year        1.000000  0.140977  0.169537  ...  0.003484   -0.214491  -0.083019
# refund      0.140977  1.000000  0.969427  ...  0.003768    0.017101   0.068768
# fee         0.169537  0.969427  1.000000  ...  0.064893    0.002252   0.063632
# has_paid    0.136060  0.094061  0.117695  ...  0.021294    0.310678   0.023724
# income_근로   0.124501 -0.079797 -0.079523  ... -0.001553   -0.356355   0.198387
# income_사업   0.153693  0.610592  0.601112  ...  0.032264   -0.124102   0.062831
# income_기타   0.036665  0.507695  0.531414  ...  0.020650   -0.003634   0.047211
# 환급금_수수료율    0.003484  0.003768  0.064893  ...  1.000000    0.004362   0.012321
# income_cat -0.214491  0.017101  0.002252  ...  0.004362    1.000000   0.008355
# age_group  -0.083019  0.068768  0.063632  ...  0.012321    0.008355   1.000000
#
# [10 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 10))
sns.boxplot(data=df)
